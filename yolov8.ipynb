# %% [markdown]
# # Install from PIP

# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ultralytics in /home/rimuru/.local/lib/python3.12/site-packages (8.2.49)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in /usr/lib/python3.12/site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (3.9.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/lib/python3.12/site-packages (from ultralytics) (10.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/lib/python3.12/site-packages (from ultralytics) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /usr/lib/python3.12/site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (1.14.0)
# Requirement already satisfied: torch>=1.8.0 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (2.3.1)
# Requirement already satisfied: torchvision>=0.9.0 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (0.18.1)
# Requirement already satisfied: tqdm>=4.64.0 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (4.66.4)
# Requirement already satisfied: psutil in /usr/lib/python3.12/site-packages (from ultralytics) (5.9.8)
# Requirement already satisfied: py-cpuinfo in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (2.2.2)
# Requirement already satisfied: seaborn>=0.11.0 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /home/rimuru/.local/lib/python3.12/site-packages (from ultralytics) (2.0.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/rimuru/.local/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/rimuru/.local/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/rimuru/.local/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/rimuru/.local/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/rimuru/.local/lib/python3.12/site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/rimuru/.local/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/rimuru/.local/lib/python3.12/site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/lib/python3.12/site-packages (from requests>=2.23.0->ultralytics) (1.26.18)
# Requirement already satisfied: filelock in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (4.12.0)
# Requirement already satisfied: sympy in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (1.12.1)
# Requirement already satisfied: networkx in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/rimuru/.local/lib/python3.12/site-packages (from torch>=1.8.0->ultralytics) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/rimuru/.local/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.8.0->ultralytics) (12.5.82)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/rimuru/.local/lib/python3.12/site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /home/rimuru/.local/lib/python3.12/site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)

# %% [markdown]
# # Check yolov8

# %%
# !yolo task=detect \
mode=predict \
model=yolov8n.pt \
conf=0.25 \
source='https://media.roboflow.com/notebooks/examples/dog.jpeg'
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.25M/6.25M [00:01<00:00, 3.87MB/s]
# Ultralytics YOLOv8.2.49 🚀 Python-3.12.3 torch-2.3.1+cu121 CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients, 8.7 GFLOPs
#
# Downloading https://media.roboflow.com/notebooks/examples/dog.jpeg to 'dog.jpeg'...
# 100%|█████████████████████████████████████████| 104k/104k [00:00<00:00, 790kB/s]
# image 1/1 /home/rimuru/Documents/detect_money_uk/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 171.6ms
# Speed: 3.7ms preprocess, 171.6ms inference, 10.1ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # Train model

# %%
# !yolo task=detect \
mode=train \
model=yolov8s.pt \
data=data/data.yaml \
epochs=5 \
imgsz=640
# Out:
# Ultralytics YOLOv8.2.49 🚀 Python-3.12.3 torch-2.3.1+cu121 CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=data/data.yaml, epochs=5, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# Overriding model.yaml nc=80 with nc=20
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2123788  ultralytics.nn.modules.head.Detect           [20, [128, 256, 512]]
# Model summary: 225 layers, 11143340 parameters, 11143324 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning /home/rimuru/Documents/detect_money_uk/data/labels.cache... 66 i
# train: WARNING ⚠️ /home/rimuru/Documents/detect_money_uk/data/images/34a1b3c4-kollekcijz-ykrainskih-obihodnyh-monet-1.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/rimuru/Documents/detect_money_uk/data/images/3b1989d1-big_monety-ukrainy-moneti-50-kop_3543673.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/rimuru/Documents/detect_money_uk/data/images/9252131d-35243_1_2.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/rimuru/Documents/detect_money_uk/data/images/f69ef244-c1a5beee-490d-4887-999a-53b491e7c3d6.jpg: 1 duplicate labels removed
# val: Scanning /home/rimuru/Documents/detect_money_uk/data/labels.cache... 66 ima
# train: WARNING ⚠️ /home/rimuru/Documents/detect_money_uk/data/images/34a1b3c4-kollekcijz-ykrainskih-obihodnyh-monet-1.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/rimuru/Documents/detect_money_uk/data/images/3b1989d1-big_monety-ukrainy-moneti-50-kop_3543673.jpg: 1 duplicate labels removed
# train: WARNING ⚠️ /home/rimuru/Documents/detect_money_uk/data/images/9252131d-35243_1_2.jpg: 2 duplicate labels removed
# train: WARNING ⚠️ /home/rimuru/Documents/detect_money_uk/data/images/f69ef244-c1a5beee-490d-4887-999a-53b491e7c3d6.jpg: 1 duplicate labels removed
# Plotting labels to runs/detect/train3/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000417, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 0 dataloader workers
# Logging results to runs/detect/train3
# Starting training for 5 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/5         0G      1.401      4.803      1.558         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         66        591     0.0782      0.126     0.0209      0.015
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         2/5         0G      1.257      4.232       1.34         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         66        591     0.0314      0.347     0.0441      0.034
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         3/5         0G      1.482      3.822      1.602         15        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         66        591     0.0649      0.198     0.0756     0.0578
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         4/5         0G      1.179      2.845      1.323         24        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         66        591     0.0867      0.255      0.105     0.0826
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         5/5         0G     0.9756      3.178      1.222         46        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         66        591      0.123      0.306      0.127      0.101
#
# 5 epochs completed in 0.162 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 22.5MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics YOLOv8.2.49 🚀 Python-3.12.3 torch-2.3.1+cu121 CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# Model summary (fused): 168 layers, 11133324 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all         66        591      0.122      0.306      0.126     0.0993
#                   bn_1          8         13     0.0298     0.0769     0.0196     0.0163
#                  bn_10         10         13     0.0554      0.231     0.0393     0.0208
#                 bn_100         17         34     0.0783      0.147     0.0856     0.0325
#                bn_1000          6          9     0.0325      0.778      0.376      0.334
#                   bn_2          9         13          0          0          0          0
#                  bn_20         16         23    0.00628     0.0435    0.00603    0.00351
#                 bn_200         15         32     0.0327      0.281     0.0343     0.0146
#                   bn_5          9         20      0.192       0.25      0.124     0.0524
#                  bn_50         10         15      0.121      0.333     0.0999     0.0851
#                 bn_500         13         40      0.154      0.075     0.0263     0.0197
#                 coin_1          9         22      0.156      0.318      0.119      0.101
#                coin_10         12         89      0.222      0.798      0.307      0.227
#             coin_10_bn          4          8      0.133        0.5      0.166      0.153
#              coin_1_bn          9         24      0.113     0.0833     0.0662     0.0619
#                 coin_2          7         22      0.105      0.318      0.057     0.0412
#                coin_25         10         46      0.361      0.304      0.223      0.196
#              coin_2_bn          5          9          0          0    0.00845    0.00783
#                 coin_5         10         43       0.19      0.153      0.144     0.0919
#                coin_50         11        108      0.278      0.935      0.447      0.379
#              coin_5_bn          4          8      0.189        0.5      0.169      0.149
# Speed: 2.0ms preprocess, 340.7ms inference, 0.0ms loss, 58.3ms postprocess per image
# Results saved to runs/detect/train3
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# # Detect objects

# %%
# !yolo task=detect \
mode=predict \
model=runs/detect/train3/weights/best.pt \
conf=0.25 \
source='examples/coins.jpg'
# Out:
# Ultralytics YOLOv8.2.49 🚀 Python-3.12.3 torch-2.3.1+cu121 CPU (AMD Ryzen 9 5900HS with Radeon Graphics)
# Model summary (fused): 168 layers, 11133324 parameters, 0 gradients, 28.5 GFLOPs
#
# image 1/1 /home/rimuru/Documents/detect_money_uk/examples/coins.jpg: 256x640 5 bn_200s, 2 coin_10s, 1 coin_50, 156.2ms
# Speed: 1.0ms preprocess, 156.2ms inference, 2.4ms postprocess per image at shape (1, 3, 256, 640)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
